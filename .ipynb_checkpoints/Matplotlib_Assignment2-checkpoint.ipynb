# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
x=np.array([1,2,3,4,5,6,7])
y=np.array([1,2,3,5,8,13,20])

plt.title("Line graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x, y, color ="c")
plt.show()

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
z = [3, 5, 11, 20, 15, 29, 31]

# %%
plt.plot(x, y, z, marker = 'o', markersize = 10,
         markerfacecolor = 'r', markeredgewidth= 3, markeredgecolor= 'y',linestyle = 'dashed', linewidth = '3');
plt.legend(['Normal','Fast'], shadow = True, loc = 'upper left');

# %% [markdown]
# # Q4: Display multiple line charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
#super title = my data visulaization assignment
plt.figure(figsize=[20,10])
plt.suptitle('my data visulaization assignment',fontsize = 20)


#first
plt.subplot(2,2,1)
plt.title("First")
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])
plt.plot(x_plot1, y_plot1,linewidth = '3');
#second
plt.subplot(2,1,2)
plt.title("Second")
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])
plt.plot(x_plot2, y_plot2, linewidth = '3');
#third
plt.subplot(2,2,2)
plt.title("Third")
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])
plt.plot(x_plot3, y_plot3, markeredgecolor= 'y', linewidth = '3');

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
series = ['Breaking Bad', 'Game of Thrones', 'House']
ratings = [4.5, 8.4, 9.7]

# %%
positions = np.arange(0,3)
plt.bar(positions, ratings, color='lightgrey', width=0.5)
plt.xticks(positions, series)
plt.xlabel('Series')
plt.ylabel('Rating')
plt.title('Top Series Rating')
plt.show()

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
Age = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11]
Speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78]
col = ['yellow', 'cyan', 'blue', 'orange', 'purple', 'pink', 'magenta', 'red', 'black', 'gray']
plt.scatter(Age, Speed, s=350, alpha=0.4, c=col)
plt.xlabel('Age')
plt.ylabel('Speed')
plt.show()

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
libraries = ['numpy', 'pandas', 'matplotlib', 'seaborn', 'plotly', 'scikit learn']
skills = [8, 9, 7, 6, 9, 8]
colors = ['orange', 'lightgreen', 'cyan', 'gold', 'lightpink', 'lightgrey']
explode = [0.3 if library == 'matplotlib' else 0 for library in libraries]
shadow = True
plt.pie(skills, explode=explode, labels=libraries, colors=colors, autopct='%1.1f%%', shadow=shadow)
plt.show()

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
import pandas as pd
import numpy as np
import uuid
from faker import Faker



df1 = pd.DataFrame(index=range(250))



import random
 



#1
df1['Jeddah']=''
df1['Jeddah'] = np.random.randint(150,220, size=len(df1))
#2
df1['Makkah']=''
df1['Makkah'] = np.random.randint(150,220, size=len(df1))
#3
df1['Riyadh']=''
df1['Riyadh'] = np.random.randint(150,220, size=len(df1))
#4
df1['Dammam']=''
df1['Dammam'] = np.random.randint(150,220, size=len(df1))
#5
df1['Haffof']=''
df1['Haffof'] = np.random.randint(150,220, size=len(df1))
#6
df1['Madinah']=''
df1['Madinah'] =np.random.randint(150,220, size=len(df1))
#7
df1['Tabok']=''
df1['Tabok'] = np.random.randint(150,220, size=len(df1))
#8
df1['Sharora']=''
df1['Sharora'] = np.random.randint(150,220, size=len(df1))
#9
df1['Tabok']=''
df1['Tabok'] = np.random.randint(150,220, size=len(df1))
#10
df1['Hafr albatin']=''
df1['Hafr albatin'] = np.random.randint(150,220, size=len(df1))
#11
df1['Abha']=''
df1['Abha'] = np.random.randint(150,220, size=len(df1))
#12
df1['Albaha']=''
df1['Albaha'] = np.random.randint(150,220, size=len(df1))
#13
df1['Jubail']=''
df1['Jubail'] = np.random.randint(150,220, size=len(df1))
#14
df1['qateef']=''
df1['qateef'] = np.random.randint(150,220, size=len(df1))
#15
df1['Rabigh']=''
df1['Rabigh'] = np.random.randint(150,220, size=len(df1))

# %%
df1.hist();

# %%
df1['Jeddah'].hist(bins=15, edgecolor="red", color="cyan")
# Out:
# <AxesSubplot: >
